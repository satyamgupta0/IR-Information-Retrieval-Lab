# %%
# ! Reference - https://github.com/xflr6/concepts
! pip install concepts
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# importing concept library
import concepts
from concepts import Context, load_cxt, make_context, load_csv,load
import numpy as np
import pandas as pd

# Creating the context from the String
c = Context.fromstring('''
           |human|knight|king |mysterious|
King Arthur|  X  |  X   |  X  |          |
Sir Robin  |  X  |  X   |     |          |
holy grail |     |      |     |     X    |
''')
c.lattice.graphviz()

# %% [markdown]
# # Formal Concept
# '''
# If A' = B and B'=A (or A'=A) then the pair (A,B) is a concept
# Here A is Extent and B is intent
# '''

# %%
# taking a concept from concept file https://github.com/xflr6/concepts/blob/master/examples/tealady.cxt

context=load_cxt('./telady.cxt')

# %%
context.lattice.graphviz()

# %%
atr_size = 12
arr = np.random.randint(2, size=(atr_size, atr_size))
df = pd.DataFrame(data=arr, columns=[f'doc{i}' for i in range(atr_size)])
new_col = [f'term{i}' for i in range(atr_size)]
df[df == 1] = 'X'
df[df == 0] = ''
df.insert(loc=0, column='', value=new_col)
df.to_csv('./dummy.csv', index=False)

# %%
context = load_csv('./dummy.csv')
context
# Out:
# <Context object mapping 12 objects to 12 properties [49921006] at 0x7f0f8ecda050>

# %%
df
# Out:
#            doc0 doc1 doc2 doc3 doc4 doc5 doc6 doc7 doc8 doc9 doc10 doc11
# 0    term0    X    X    X    X    X                   X                X
# 1    term1         X         X                   X    X
# 2    term2    X         X    X                   X
# 3    term3    X         X    X              X         X
# 4    term4         X              X         X    X               X     X
# 5    term5         X    X              X    X    X    X          X
# 6    term6    X         X    X    X    X    X         X    X
# 7    term7              X    X    X         X    X    X
# 8    term8         X    X         X    X         X         X
# 9    term9         X         X              X
# 10  term10         X    X    X    X    X    X    X    X          X     X
# 11  term11         X    X    X              X         X    X           X

# %%
context.lattice.graphviz()

# %%
# Creating concepts from txt file https://github.com/xflr6/concepts/blob/master/examples/liveinwater.txt
liveinwater = concepts.load('./liveinwater.txt') 
liveinwater
# Out:
# <Context object mapping 8 objects to 9 properties [b1e86589] at 0x7f0f8ec56550>

# %%
liveinwater.lattice.graphviz()
